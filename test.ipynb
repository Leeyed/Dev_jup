# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xx = np.linspace(0, 1, 100)
yy = -np.log(1+np.exp(-xx))

yy2 = np.log(1-xx)

plt.plot(xx, yy, label="log(1+exp(-x))")
plt.plot(xx, yy2, label="log(1-x)")
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\ls031\AppData\Local\Temp\ipykernel_9444\214521116.py:4: RuntimeWarning: divide by zero encountered in log
#   yy2 = np.log(1-xx)
